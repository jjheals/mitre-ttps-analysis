# %% [markdown]
# **Objective:** Rate threat actors based on their similarity in attack patterns.

# %%
import json 
import numpy as np 
from sklearn.metrics.pairwise import cosine_similarity
from functions.functions import name_from_id, generate_similarity_table
import pandas as pd

# %% [markdown]
# **Create arrays of attack pattern IDs and threat actor IDs to maintain the row and column orders of the matrices as indexes**
#
# Example:
# ```text
#            t1   t2   t3 ... tN
#     TA1 |  0    0    1  ... 0
#     TA2 |  1    1    1  ... 1
#     TA3 |  1    0    1  ... 1
#       . |  .    .    .   .  .
#       . |  .    .    .   .  .
#       . |  .    .    .   .  .
#     TAM |  0    1    0  ... 1
# ```
# In this example:
# - TAX is a threat actor.
# - tX is a tactic (attack pattern).
# - M is the number of threat actors.
# - N is the number of tactics.

# %% [markdown]
# #### **Load data**

# %%
# Load the necessary data
with open('data/jsons/intrusion-sets.json', 'r') as file: 
    threat_actors:list[dict] = json.load(file)
    
with open('data/jsons/attack-patterns.json', 'r') as file: 
    attack_patterns:list[dict] = json.load(file)

# %% [markdown]
# #### **Construct the matrix with threat actors for rows and attack patterns for columns**

# %%
# Get all the threat actor IDs as a list
threat_actor_ids:list[str] = [ t['id'] for t in threat_actors ]

# Get all the attack pattern IDs as a list
attack_pattern_ids:list[str] = [ a['id'] for a in attack_patterns ]

# Convert the threat actor ids to names for meaningful analysis 
threat_actor_names:list[str] = [ name_from_id(threat_actors, i) for i in threat_actor_ids ]

# Define variables for the matrix dimensions
M:int = len(threat_actor_ids)   # M := number of rows, i.e. number of threat actors
N:int = len(attack_pattern_ids) # N := number of columns, i.e. number of attack patterns 

# Construct an NxM matrix
actor_ttp_matrix:np.matrix = np.matrix(np.zeros((M,N)))

# Print details
print(f'Got M = {len(threat_actor_ids)} threat actor IDs (rows).')
print(f'Got N = {len(attack_pattern_ids)} attack pattern IDs (columns).')
# Out:
# Got M = 165 threat actor IDs (rows).
# Got N = 780 attack pattern IDs (columns).

# %% [markdown]
# #### **Populate the matrix**

# %%
# Iterate over the threat actors and add their attack patterns as appropriate
for t in threat_actors: 
    
    # Get the ID for this threat actor and find its index in threat_actor_ids
    this_threat_actor_id:str = t['id']
    this_row:int = threat_actor_ids.index(this_threat_actor_id)
     
    # Get the name and load the attack patterns for this threat actor from the JSON
    threat_actor_name:str = t['name'] 
    with open(f'data/jsons/threat-groups/{threat_actor_name.replace(" ", "-")}/attack-patterns.json', 'r') as file:
        these_attack_patterns:list[dict] = json.load(file) 
    
    # Iterate over the attack patterns for this actor
    for ap in these_attack_patterns:
        
        # Get the attack pattern's ID and find the index in attack_patterns 
        this_ap_id:str = ap['id']
        this_col:int = attack_pattern_ids.index(this_ap_id)
        
        # Set the value in actor_ttp_matrix at the ROW = this_row (i.e. threat actor ID) and COL = this_col (i.e. attack pattern ID) 
        # to 1, i.e. True to represent that this threat actor employs this attack pattern 
        actor_ttp_matrix[this_row, this_col] = 1

# Save the actor_ttp_matrix 
np.savetxt("data/analysis-outcomes/actor-attack-pattern-similarities/actor-ttp-matrix.csv", actor_ttp_matrix.astype(int), delimiter=",", fmt="%d")

# Save the matrix row and column labels
with open('data/analysis-outcomes/actor-attack-pattern-similarities/matrix-labels.json', 'w+') as file: 
    json.dump({ 'rows': threat_actor_ids, 'columns': attack_pattern_ids }, file, indent=4)

# %% [markdown]
# #### **Save results**

# %%
# Construct the similarity matrix
similarity_matrix:np.matrix = cosine_similarity(np.asarray(actor_ttp_matrix))

# Generate the similarity table from the similarity matrix
table_results, pretty_table = generate_similarity_table(
    similarity_matrix, 
    threat_actor_names, 
    table_headers = ['Actor 1', 'Actor 2', 'Similarity Rating', 'Is Alias'],
    check_if_aliases=True
)

# Convert the table to a dataframe and save it
attack_pattern_sim_df:pd.DataFrame = pd.DataFrame(table_results, columns=['Actor 1', 'Actor 2', 'Similarity Rating', 'Is Alias'])
attack_pattern_sim_df.to_csv('data/analysis-outcomes/actor-attack-pattern-similarities/attack-pattern-similarities-table.csv', index=False)

# Print the pretty table results
print(pretty_table)
# Out:
# Actor 1             Actor 2               Similarity Rating  Is Alias
# ------------------  ------------------  -------------------  ----------
# APT-C-23            None                               0     False
# APT-C-36            WIRTE                              0.6   False
# APT1                Ke3chang                           0.43  False
# APT12               APT30                              0.63  False
# APT16               Indrik Spider                      0.22  False
# APT17               POLONIUM                           0.27  False
# APT18               Metador                            0.46  False
# APT19               APT32                              0.45  False
# APT28               APT29                              0.45  False
# APT29               UNC2452                            1     True
# APT3                APT41                              0.5   False
# APT30               TA459                              0.63  False
# APT32               Lazarus Group                      0.51  False
# APT33               MuddyWater                         0.46  False
# APT34               OilRig                             1     True
# APT37               Sharpshooter                       0.5   False
# APT38               Operation Wocao                    0.43  False
# APT39               Dragonfly 2.0                      0.49  False
# APT41               APT3                               0.5   False
# APT5                FIN13                              0.42  False
# Ajax Security Team  APT30                              0.58  False
# Akira               Scattered Spider                   0.31  False
# Andariel            Elderwood                          0.46  False
# Aoqin Dragon        Ferocious Kitten                   0.41  False
# Aquatic Panda       Metador                            0.43  False
# Axiom               Dragonfly                          0.29  False
# BITTER              APT-C-36                           0.5   False
# BRONZE BUTLER       MuddyWater                         0.51  False
# BackdoorDiplomacy   Volatile Cedar                     0.35  False
# BlackOasis          Dust Storm                         0.58  False
# BlackTech           Mofang                             0.48  False
# Blue Mockingbird    APT41                              0.41  False
# Bouncing Golf       None                               0     False
# CURIUM              Dark Caracal                       0.43  False
# Carbanak            PittyTiger                         0.45  False
# Charming Kitten     None                               0     False
# Charming Kitten     None                               0     False
# Chimera             Operation Wocao                    0.55  False
# Cinnamon Tempest    Blue Mockingbird                   0.38  False
# Cleaver             PittyTiger                         0.32  False
# Cobalt Group        Patchwork                          0.47  False
# Confucius           Sidewinder                         0.59  False
# CopyKittens         DarkHydrus                         0.4   False
# CostaRicto          PittyTiger                         0.32  False
# Dark Caracal        CURIUM                             0.43  False
# DarkHydrus          Nomadic Octopus                    0.57  False
# DarkVishnya         Thrip                              0.47  False
# Darkhotel           Sidewinder                         0.47  False
# Deep Panda          ToddyCat                           0.36  False
# DragonOK            None                               0     False
# Dragonfly           Dragonfly 2.0                      0.76  False
# Dragonfly 2.0       Dragonfly                          0.76  False
# Dust Storm          BlackOasis                         0.58  False
# EXOTIC LILY         Mofang                             0.46  False
# Earth Lusca         MuddyWater                         0.47  False
# Elderwood           Mofang                             0.71  False
# Ember Bear          TA505                              0.54  False
# Equation            Strider                            0.26  False
# Evilnum             Cobalt Group                       0.35  False
# FIN10               Silence                            0.46  False
# FIN13               APT41                              0.49  False
# FIN4                Mofang                             0.52  False
# FIN5                PittyTiger                         0.43  False
# FIN6                FIN8                               0.48  False
# FIN7                LazyScripter                       0.51  False
# FIN8                Wizard Spider                      0.52  False
# Ferocious Kitten    IndigoZebra                        0.62  False
# Fox Kitten          APT39                              0.45  False
# Frankenstein        Gamaredon Group                    0.51  False
# GALLIUM             menuPass                           0.48  False
# GCMAN               Fox Kitten                         0.22  False
# GOLD SOUTHFIELD     Thrip                              0.33  False
# Gallmaker           APT30                              0.53  False
# Gamaredon Group     Frankenstein                       0.51  False
# Gelsemium           GOLD SOUTHFIELD                    0.19  False
# Gorgon Group        Nomadic Octopus                    0.55  False
# Group5              Metador                            0.27  False
# HAFNIUM             Magic Hound                        0.41  False
# HEXANE              Magic Hound                        0.43  False
# Higaisa             Darkhotel                          0.47  False
# Honeybee            Patchwork                          0.41  False
# Inception           Confucius                          0.54  False
# IndigoZebra         Ferocious Kitten                   0.62  False
# Indrik Spider       Aquatic Panda                      0.34  False
# Ke3chang            Chimera                            0.5   False
# Kimsuky             Lazarus Group                      0.52  False
# LAPSUS$             Scattered Spider                   0.29  False
# Lazarus Group       Kimsuky                            0.52  False
# LazyScripter        TA2541                             0.56  False
# Leafminer           APT33                              0.32  False
# Leviathan           Patchwork                          0.42  False
# Lotus Blossom       None                               0     False
# LuminousMoth        Patchwork                          0.41  False
# MONSOON             Patchwork                          1     True
# Machete             Rancor                             0.49  False
# Magic Hound         Sandworm Team                      0.52  False
# Malteiro            Molerats                           0.42  False
# Metador             APT18                              0.46  False
# Moafee              Ember Bear                         0.22  False
# Mofang              Elderwood                          0.71  False
# Molerats            Mofang                             0.54  False
# Moses Staff         Volatile Cedar                     0.39  False
# MoustachedBouncer   CopyKittens                        0.25  False
# MuddyWater          Sidewinder                         0.57  False
# Mustang Panda       Sidewinder                         0.57  False
# Mustard Tempest     Transparent Tribe                  0.46  False
# NEODYMIUM           None                               0     False
# Naikon              SideCopy                           0.4   False
# Night Dragon        GALLIUM                            0.35  False
# Nomadic Octopus     DarkHydrus                         0.57  False
# OilRig              APT34                              1     False
# Operation Wocao     Chimera                            0.55  False
# Orangeworm          SilverTerrier                      0.35  False
# PLATINUM            Ajax Security Team                 0.47  False
# POLONIUM            PittyTiger                         0.53  False
# PROMETHIUM          RTM                                0.34  False
# Patchwork           MONSOON                            1     False
# PittyTiger          POLONIUM                           0.53  False
# Poseidon Group      admin@338                          0.41  False
# Putter Panda        Dark Caracal                       0.29  False
# RTM                 APT30                              0.53  False
# Rancor              APT-C-36                           0.53  False
# Rocke               TeamTNT                            0.52  False
# Sandworm Team       Magic Hound                        0.52  False
# Scarlet Mimic       Ferocious Kitten                   0.41  False
# Scattered Spider    Akira                              0.31  False
# Sharpshooter        Gorgon Group                       0.51  False
# SideCopy            Sidewinder                         0.55  False
# Sidewinder          Confucius                          0.59  False
# Silence             Sharpshooter                       0.47  False
# Silent Librarian    PittyTiger                         0.39  False
# SilverTerrier       Orangeworm                         0.35  False
# Sowbug              admin@338                          0.38  False
# Stealth Falcon      Frankenstein                       0.49  False
# Stolen Pencil       APT3                               0.32  False
# Strider             Equation                           0.26  False
# Suckfly             PittyTiger                         0.32  False
# TA2541              LazyScripter                       0.56  False
# TA459               APT30                              0.63  False
# TA505               Molerats                           0.54  False
# TA551               Nomadic Octopus                    0.51  False
# TEMP.Veles          FIN10                              0.42  False
# Taidoor             Machete                            0.22  False
# TeamTNT             Rocke                              0.52  False
# The White Company   APT30                              0.5   False
# Threat Group-1314   Orangeworm                         0.35  False
# Threat Group-3390   menuPass                           0.54  False
# Thrip               DarkVishnya                        0.47  False
# ToddyCat            Operation Wocao                    0.49  False
# Tonto Team          TA459                              0.46  False
# Transparent Tribe   Mofang                             0.6   False
# Tropic Trooper      Sidewinder                         0.51  False
# Turla               Operation Wocao                    0.46  False
# UNC2452             APT29                              1     True
# Volatile Cedar      Moses Staff                        0.39  False
# Volt Typhoon        Operation Wocao                    0.51  False
# WIRTE               APT-C-36                           0.6   False
# Whitefly            BITTER                             0.42  False
# Windigo             Dust Storm                         0.44  False
# Windshift           Sidewinder                         0.54  False
# Winnti Group        Darkhotel                          0.33  False
# Wizard Spider       FIN8                               0.52  False
# ZIRCONIUM           Kimsuky                            0.42  False
# admin@338           Darkhotel                          0.46  False
# menuPass            Threat Group-3390                  0.54  False
