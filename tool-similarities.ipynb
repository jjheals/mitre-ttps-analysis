# %% [markdown]
# **Objective:** Rate threat actors based on their similarity in malware from previous attacks.

# %%
import json 
import numpy as np 
from sklearn.metrics.pairwise import cosine_similarity
from functions.functions import name_from_id, generate_similarity_table
import pandas as pd

# %% [markdown]
# **Create arrays of tool IDs and threat actor IDs to maintain the row and column orders of the matrices as indexes**
#
# Example:
# ```text
#            t1   t2   t3 ... tN
#     TA1 |  0    0    1  ... 0
#     TA2 |  1    1    1  ... 1
#     TA3 |  1    0    1  ... 1
#       . |  .    .    .   .  .
#       . |  .    .    .   .  .
#       . |  .    .    .   .  .
#     TAM |  0    1    0  ... 1
# ```
# In this example:
# - TAX is a threat actor.
# - tX is a tool.
# - M is the number of threat actors.
# - N is the number of tools.

# %% [markdown]
# #### **Load data**

# %%
# Load the necessary data
with open('data/jsons/intrusion-sets.json', 'r') as file: 
    threat_actors:list[dict] = json.load(file)
    
with open('data/jsons/tools.json', 'r') as file: 
    tools:list[dict] = json.load(file)

# %% [markdown]
# #### **Construct the matrix with threat actors for rows and malware for columns**

# %%
# Get all the threat actor IDs as a list
threat_actor_ids:list[str] = [ t['id'] for t in threat_actors ]

# Get all the tool IDs as a list
tool_ids:list[str] = [ t['id'] for t in tools ]

# Convert the threat actor ids to names for meaningful analysis 
threat_actor_names:list[str] = [ name_from_id(threat_actors, i) for i in threat_actor_ids ]

# Define variables for the matrix dimensions
M:int = len(threat_actor_ids)   # M := number of rows, i.e. number of threat actors
N:int = len(tool_ids) # N := number of columns, i.e. number of tools

# Construct an NxM matrix
actor_tool_matrix:np.matrix = np.matrix(np.zeros((M,N)))

# Print details
print(f'Got M = {M} threat actor IDs (rows).')
print(f'Got N = {N} tool IDs (columns).')
# Out:
# Got M = 165 threat actor IDs (rows).
# Got N = 86 tool IDs (columns).

# %% [markdown]
# #### **Populate the matrix**

# %%
# Iterate over the threat actors and add their malware as appropriate
for t in threat_actors: 
    
    # Get the ID for this threat actor and find its index in threat_actor_ids
    this_threat_actor_id:str = t['id']
    this_row:int = threat_actor_ids.index(this_threat_actor_id)
     
    # Get the name and load the malwares for this threat actor from the JSON
    threat_actor_name:str = t['name'] 
    with open(f'data/jsons/threat-groups/{threat_actor_name.replace(" ", "-")}/tools.json', 'r') as file:
        these_tools:list[dict] = json.load(file) 
    
    # Iterate over the malware for this actor
    for t in these_tools:
        
        # Get the attack pattern's ID and find the index in malware_ids
        this_tool_id:str = t['id']
        this_col:int = tool_ids.index(this_tool_id)
        
        # Set the value in actor_ttp_matrix at the ROW = this_row (i.e. threat actor ID) and COL = this_col (i.e. malware ID) 
        # to 1, i.e. True to represent that this threat actor uses this malware
        actor_tool_matrix[this_row, this_col] = 1

# Save the actor_ttp_matrix 
np.savetxt("data/analysis-outcomes/actor-tool-similarities/actor-tool-matrix.csv", actor_tool_matrix.astype(float), delimiter=",", fmt="%f")

# Save the matrix row and column labels
with open('data/analysis-outcomes/actor-tool-similarities/matrix-labels.json', 'w+') as file: 
    json.dump({ 'rows': threat_actor_ids, 'columns': tool_ids }, file, indent=4)

# %% [markdown]
# #### **Save results**

# %%
# Construct the similarity matrix
similarity_matrix:np.matrix = cosine_similarity(np.asarray(actor_tool_matrix))

# Save the similarity matrix 
np.savetxt("data/analysis-outcomes/actor-tool-similarities/actor-tool-similarity-matrix.csv", similarity_matrix.astype(float), delimiter=",", fmt="%f")

# Generate the similarity table from the similarity matrix
table_results, pretty_table = generate_similarity_table(
    similarity_matrix, 
    threat_actor_names, 
    table_headers = ['Actor 1', 'Actor 2', 'Similarity Rating', 'Is Alias'],
    check_if_aliases=True
)

# Convert the table to a dataframe and save it
tool_sim_df:pd.DataFrame = pd.DataFrame(table_results, columns=['Actor 1', 'Actor 2', 'Similarity Rating', 'Is Alias'])
tool_sim_df.to_csv('data/analysis-outcomes/actor-tool-similarities/tool-similarities-table.csv', index=False)

# Print the pretty table 
print(pretty_table)
# Out:
# Actor 1             Actor 2              Similarity Rating  Is Alias
# ------------------  -----------------  -------------------  ----------
# APT-C-23            None                              0     False
# APT-C-36            TA2541                            0.71  False
# APT1                Threat Group-3390                 0.52  False
# APT12               GALLIUM                           0.3   False
# APT16               None                              0     False
# APT17               None                              0     False
# APT18               Honeybee                          0.5   False
# APT19               Frankenstein                      1     False
# APT28               APT38                             0.47  False
# APT29               UNC2452                           1     True
# APT3                Evilnum                           0.71  False
# APT30               None                              0     False
# APT32               APT38                             0.63  False
# APT33               APT38                             0.47  False
# APT34               OilRig                            1     True
# APT37               None                              0     False
# APT38               DarkHydrus                        0.71  False
# APT39               FIN6                              0.57  False
# APT41               HEXANE                            0.63  False
# APT5                APT38                             0.63  False
# Ajax Security Team  Magic Hound                       0.43  False
# Akira               FIN6                              0.67  False
# Andariel            None                              0     False
# Aoqin Dragon        None                              0     False
# Aquatic Panda       None                              0     False
# Axiom               None                              0     False
# BITTER              None                              0     False
# BRONZE BUTLER       GALLIUM                           0.57  False
# BackdoorDiplomacy   Mustang Panda                     0.58  False
# BlackOasis          None                              0     False
# BlackTech           Moses Staff                       1     False
# Blue Mockingbird    DarkHydrus                        1     False
# Bouncing Golf       None                              0     False
# CURIUM              None                              0     False
# Carbanak            Stolen Pencil                     0.82  False
# Charming Kitten     None                              0     False
# Charming Kitten     None                              0     False
# Chimera             APT38                             0.63  False
# Cinnamon Tempest    HAFNIUM                           0.41  False
# Cleaver             Stolen Pencil                     1     False
# Cobalt Group        Stolen Pencil                     0.82  False
# Confucius           None                              0     False
# CopyKittens         Frankenstein                      1     False
# CostaRicto          Moses Staff                       0.58  False
# Dark Caracal        None                              0     False
# DarkHydrus          Blue Mockingbird                  1     False
# DarkVishnya         Moses Staff                       0.71  False
# Darkhotel           None                              0     False
# Deep Panda          ToddyCat                          0.67  False
# DragonOK            None                              0     False
# Dragonfly           Dragonfly 2.0                     0.94  False
# Dragonfly 2.0       Dragonfly                         0.94  False
# Dust Storm          None                              0     False
# EXOTIC LILY         None                              0     False
# Earth Lusca         Volt Typhoon                      0.47  False
# Elderwood           None                              0     False
# Ember Bear          None                              0     False
# Equation            None                              0     False
# Evilnum             Inception                         1     False
# FIN10               Frankenstein                      1     False
# FIN13               Indrik Spider                     0.5   False
# FIN4                None                              0     False
# FIN5                Cobalt Group                      0.58  False
# FIN6                Stolen Pencil                     0.71  False
# FIN7                TA505                             0.67  False
# FIN8                HAFNIUM                           0.58  False
# Ferocious Kitten    Tropic Trooper                    1     False
# Fox Kitten          Moses Staff                       0.71  False
# Frankenstein        CopyKittens                       1     False
# GALLIUM             BRONZE BUTLER                     0.57  False
# GCMAN               None                              0     False
# GOLD SOUTHFIELD     MuddyWater                        0.33  False
# Gallmaker           None                              0     False
# Gamaredon Group     Deep Panda                        0.58  False
# Gelsemium           DarkHydrus                        1     False
# Gorgon Group        LazyScripter                      0.63  False
# Group5              None                              0     False
# HAFNIUM             Moses Staff                       0.71  False
# HEXANE              APT41                             0.63  False
# Higaisa             Rancor                            0.71  False
# Honeybee            APT18                             0.5   False
# Inception           Evilnum                           1     False
# IndigoZebra         None                              0     False
# Indrik Spider       Stolen Pencil                     0.71  False
# Ke3chang            Volt Typhoon                      0.71  False
# Kimsuky             Stolen Pencil                     0.71  False
# LAPSUS$             DarkHydrus                        1     False
# Lazarus Group       Carbanak                          0.52  False
# LazyScripter        Gorgon Group                      0.63  False
# Leafminer           Stolen Pencil                     0.71  False
# Leviathan           CostaRicto                        0.44  False
# Lotus Blossom       None                              0     False
# LuminousMoth        None                              0     False
# MONSOON             Patchwork                         1     True
# Machete             None                              0     False
# Magic Hound         Volt Typhoon                      0.61  False
# Malteiro            None                              0     False
# Metador             None                              0     False
# Moafee              None                              0     False
# Mofang              None                              0     False
# Molerats            None                              0     False
# Moses Staff         BlackTech                         1     False
# MoustachedBouncer   None                              0     False
# MuddyWater          FIN7                              0.5   False
# Mustang Panda       BackdoorDiplomacy                 0.58  False
# Mustard Tempest     None                              0     False
# NEODYMIUM           None                              0     False
# Naikon              Deep Panda                        0.65  False
# Night Dragon        Moses Staff                       0.58  False
# Nomadic Octopus     None                              0     False
# OilRig              APT34                             1     False
# Operation Wocao     TA505                             0.55  False
# Orangeworm          admin@338                         0.76  False
# PLATINUM            None                              0     False
# POLONIUM            None                              0     False
# PROMETHIUM          None                              0     False
# Patchwork           MONSOON                           1     False
# PittyTiger          DarkHydrus                        0.71  False
# Poseidon Group      None                              0     False
# Putter Panda        None                              0     False
# RTM                 None                              0     False
# Rancor              Higaisa                           0.71  False
# Rocke               None                              0     False
# Sandworm Team       APT38                             0.63  False
# Scarlet Mimic       None                              0     False
# Scattered Spider    Evilnum                           0.58  False
# Sharpshooter        None                              0     False
# SideCopy            None                              0     False
# Sidewinder          LazyScripter                      0.45  False
# Silence             Frankenstein                      0.58  False
# Silent Librarian    None                              0     False
# SilverTerrier       None                              0     False
# Sowbug              None                              0     False
# Stealth Falcon      None                              0     False
# Stolen Pencil       Cleaver                           1     False
# Strider             None                              0     False
# Suckfly             None                              0     False
# TA2541              APT-C-36                          0.71  False
# TA459               None                              0     False
# TA505               FIN7                              0.67  False
# TA551               None                              0     False
# TEMP.Veles          Stolen Pencil                     1     False
# Taidoor             None                              0     False
# TeamTNT             Evilnum                           0.58  False
# The White Company   None                              0     False
# Threat Group-1314   Moses Staff                       0.71  False
# Threat Group-3390   Volt Typhoon                      0.67  False
# Thrip               Stolen Pencil                     1     False
# ToddyCat            Deep Panda                        0.67  False
# Tonto Team          PittyTiger                        0.71  False
# Transparent Tribe   None                              0     False
# Tropic Trooper      Ferocious Kitten                  1     False
# Turla               OilRig                            0.67  False
# UNC2452             APT29                             1     True
# Volatile Cedar      None                              0     False
# Volt Typhoon        Ke3chang                          0.71  False
# WIRTE               Frankenstein                      1     False
# Whitefly            DarkHydrus                        1     False
# Windigo             None                              0     False
# Windshift           None                              0     False
# Winnti Group        None                              0     False
# Wizard Spider       Akira                             0.54  False
# ZIRCONIUM           None                              0     False
# admin@338           Orangeworm                        0.76  False
# menuPass            Sandworm Team                     0.52  False
